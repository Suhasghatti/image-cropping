# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
img = cv2.imread(r'C:\\Users\\admin\\Downloads\\srk.jpg', 1)
plt.imshow(img)

# %%
# Crop the image using the slice notation on numpy array
cropped = img[0:600, 500:1300]

# Display the cropped image
cv2.imshow("Cropped Image", cropped)
cv2.waitKey(0)
cv2.destroyAllWindows()
